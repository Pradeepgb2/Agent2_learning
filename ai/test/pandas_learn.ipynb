# %%
import pandas as pd

# %%
s= pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df= pd.read_csv('employees_past_week.csv', index_col=False)
df.head()
# Out:
# C:\Users\Narasimha\AppData\Local\Temp\ipykernel_22940\2061575603.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df= pd.read_csv('employees_past_week.csv', index_col=False)
#                 email_id            name                role  \
# 0      john.doe@acme.com        John Doe   Software Engineer
# 1  jane.smith@globex.com      Jane Smith     Product Manager
# 2   robert.j@initech.com  Robert Johnson        Data Analyst
# 3   emily.c@umbrella.com     Emily Clark  Marketing Director
# 4    michael.b@hooli.com   Michael Brown                 CTO
#
#        company_name company_location
# 0  ACME Corporation    San Francisco
# 1       Globex Inc.         New York
# 2           Initech           Boston
# 3     Umbrella Corp           London
# 4             Hooli        Palo Alto

# %%
df.tail()
# Out:
#                    email_id           name                        role  \
# 258   damon.j@robostack.com  Damon Jenkins  Robotics Controls Engineer
# 259   callie.p@bluestar.com  Callie Parker                 Tech Writer
# 260    matthew.s@xensys.com   Matthew Shaw                Backend Lead
# 261    ariel.r@brightai.com    Ariel Reyes                  AI Trainer
# 262  eduardo.k@aeroflow.com   Eduardo King          Operations Manager
#
#       company_name company_location
# 258      RoboStack            Tokyo
# 259       BlueStar         New York
# 260         XenSys          Chicago
# 261  BrightAI Labs         San Jose
# 262       AeroFlow          Toronto

# %%
df.columns
# Out:
# Index(['email_id', 'name', 'role', 'company_name', 'company_location'], dtype='object')

# %%
df= pd.read_csv("students.csv", index_col=False)
df.head()
# Out:
#    student_id     name  age  marks  subject      city
# 0         101    Alice   23   85.0     Math  New York
# 1         102      Bob   24   78.0  Science   Chicago
# 2         103  Charlie   22    NaN     Math  New York
# 3         104    David   25   92.0  Science     Texas
# 4         105      Eva   23    NaN  English   Chicago

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  8 non-null      int64
#  1   name        8 non-null      object
#  2   age         8 non-null      int64
#  3   marks       5 non-null      float64
#  4   subject     8 non-null      object
#  5   city        8 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 516.0+ bytes

# %%
df.describe()
# Out:
#        student_id        age      marks
# count     8.00000   8.000000   5.000000
# mean    104.50000  23.250000  82.000000
# std       2.44949   1.035098   9.823441
# min     101.00000  22.000000  67.000000
# 25%     102.75000  22.750000  78.000000
# 50%     104.50000  23.000000  85.000000
# 75%     106.25000  24.000000  88.000000
# max     108.00000  25.000000  92.000000

# %%
df["age"]
# Out:
# 0    23
# 1    24
# 2    22
# 3    25
# 4    23
# 5    24
# 6    22
# 7    23
# Name: age, dtype: int64

# %%
df[["age", "name"]]
# Out:
#    age     name
# 0   23    Alice
# 1   24      Bob
# 2   22  Charlie
# 3   25    David
# 4   23      Eva
# 5   24    Frank
# 6   22    Grace
# 7   23    Helen

# %%
df.iloc[2]
# Out:
# student_id         103
# name           Charlie
# age                 22
# marks              NaN
# subject           Math
# city          New York
# Name: 2, dtype: object

# %%
df.iloc[2, 0:2]
# Out:
# student_id        103
# name          Charlie
# Name: 2, dtype: object

# %%
df.loc[1, "name":"age"]
# Out:
# name    Bob
# age      24
# Name: 1, dtype: object

# %%
df["age"]>23
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# Name: age, dtype: bool

# %%
df[df["age"]>23]
# Out:
#    student_id   name  age  marks  subject     city
# 1         102    Bob   24   78.0  Science  Chicago
# 3         104  David   25   92.0  Science    Texas
# 5         106  Frank   24   67.0     Math    Texas

# %%
df.isnull()
# Out:
#    student_id   name    age  marks  subject   city
# 0       False  False  False  False    False  False
# 1       False  False  False  False    False  False
# 2       False  False  False   True    False  False
# 3       False  False  False  False    False  False
# 4       False  False  False   True    False  False
# 5       False  False  False  False    False  False
# 6       False  False  False  False    False  False
# 7       False  False  False   True    False  False

# %%
df.isnull().sum()
# Out:
# student_id    0
# name          0
# age           0
# marks         3
# subject       0
# city          0
# dtype: int64

# %%
df.dropna()
# Out:
#    student_id   name  age  marks  subject      city
# 0         101  Alice   23   85.0     Math  New York
# 1         102    Bob   24   78.0  Science   Chicago
# 3         104  David   25   92.0  Science     Texas
# 5         106  Frank   24   67.0     Math     Texas
# 6         107  Grace   22   88.0  English  New York

# %%
df.dropna(subset=["age"])
# Out:
#    student_id     name  age  marks  subject      city
# 0         101    Alice   23   85.0     Math  New York
# 1         102      Bob   24   78.0  Science   Chicago
# 2         103  Charlie   22    NaN     Math  New York
# 3         104    David   25   92.0  Science     Texas
# 4         105      Eva   23    NaN  English   Chicago
# 5         106    Frank   24   67.0     Math     Texas
# 6         107    Grace   22   88.0  English  New York
# 7         108    Helen   23    NaN  Science     Texas

# %%
df["marks"]= df["marks"].fillna(df["marks"].mean())

# %%
df
# Out:
#    student_id     name  age  marks  subject      city
# 0         101    Alice   23   85.0     Math  New York
# 1         102      Bob   24   78.0  Science   Chicago
# 2         103  Charlie   22   82.0     Math  New York
# 3         104    David   25   92.0  Science     Texas
# 4         105      Eva   23   82.0  English   Chicago
# 5         106    Frank   24   67.0     Math     Texas
# 6         107    Grace   22   88.0  English  New York
# 7         108    Helen   23   82.0  Science     Texas

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values("name", ascending=False)
# Out:
#    student_id     name  age  marks  subject      city
# 7         108    Helen   23   82.0  Science     Texas
# 6         107    Grace   22   88.0  English  New York
# 5         106    Frank   24   67.0     Math     Texas
# 4         105      Eva   23   82.0  English   Chicago
# 3         104    David   25   92.0  Science     Texas
# 2         103  Charlie   22   82.0     Math  New York
# 1         102      Bob   24   78.0  Science   Chicago
# 0         101    Alice   23   85.0     Math  New York

# %%
df.sort_values("age")
# Out:
#    student_id     name  age  marks  subject      city
# 2         103  Charlie   22   82.0     Math  New York
# 6         107    Grace   22   88.0  English  New York
# 0         101    Alice   23   85.0     Math  New York
# 4         105      Eva   23   82.0  English   Chicago
# 7         108    Helen   23   82.0  Science     Texas
# 1         102      Bob   24   78.0  Science   Chicago
# 5         106    Frank   24   67.0     Math     Texas
# 3         104    David   25   92.0  Science     Texas

# %%
df.groupby("city")["marks"].mean()
# Out:
# city
# Chicago     80.000000
# New York    85.000000
# Texas       80.333333
# Name: marks, dtype: float64

# %%
df["passed"] = df["marks"] >= 70

# %%
df
# Out:
#    student_id     name  age  marks  subject      city  passed
# 0         101    Alice   23   85.0     Math  New York    True
# 1         102      Bob   24   78.0  Science   Chicago    True
# 2         103  Charlie   22   82.0     Math  New York    True
# 3         104    David   25   92.0  Science     Texas    True
# 4         105      Eva   23   82.0  English   Chicago    True
# 5         106    Frank   24   67.0     Math     Texas   False
# 6         107    Grace   22   88.0  English  New York    True
# 7         108    Helen   23   82.0  Science     Texas    True

# %%
df["marks"]+=5

# %%
df
# Out:
#    student_id     name  age  marks  subject      city  passed
# 0         101    Alice   23   90.0     Math  New York    True
# 1         102      Bob   24   83.0  Science   Chicago    True
# 2         103  Charlie   22   87.0     Math  New York    True
# 3         104    David   25   97.0  Science     Texas    True
# 4         105      Eva   23   87.0  English   Chicago    True
# 5         106    Frank   24   72.0     Math     Texas   False
# 6         107    Grace   22   93.0  English  New York    True
# 7         108    Helen   23   87.0  Science     Texas    True

# %%
df.rename(columns={"marks": "score"})
# Out:
#    student_id     name  age  score  subject      city  passed
# 0         101    Alice   23   90.0     Math  New York    True
# 1         102      Bob   24   83.0  Science   Chicago    True
# 2         103  Charlie   22   87.0     Math  New York    True
# 3         104    David   25   97.0  Science     Texas    True
# 4         105      Eva   23   87.0  English   Chicago    True
# 5         106    Frank   24   72.0     Math     Texas   False
# 6         107    Grace   22   93.0  English  New York    True
# 7         108    Helen   23   87.0  Science     Texas    True

# %%
df
# Out:
#    student_id     name  age  marks  subject      city  passed
# 0         101    Alice   23   90.0     Math  New York    True
# 1         102      Bob   24   83.0  Science   Chicago    True
# 2         103  Charlie   22   87.0     Math  New York    True
# 3         104    David   25   97.0  Science     Texas    True
# 4         105      Eva   23   87.0  English   Chicago    True
# 5         106    Frank   24   72.0     Math     Texas   False
# 6         107    Grace   22   93.0  English  New York    True
# 7         108    Helen   23   87.0  Science     Texas    True

# %%
df.rename(columns={"marks": "score"}, inplace=True) # Use inplace = True to modify the original df directly.

# %%
df
# Out:
#    student_id     name  age  score  subject      city  passed
# 0         101    Alice   23   90.0     Math  New York    True
# 1         102      Bob   24   83.0  Science   Chicago    True
# 2         103  Charlie   22   87.0     Math  New York    True
# 3         104    David   25   97.0  Science     Texas    True
# 4         105      Eva   23   87.0  English   Chicago    True
# 5         106    Frank   24   72.0     Math     Texas   False
# 6         107    Grace   22   93.0  English  New York    True
# 7         108    Helen   23   87.0  Science     Texas    True

# %%
import pandas as pd

df = pd.read_csv("students.csv")

# Fill missing marks with average
df["marks"] = df["marks"].fillna(df["marks"].mean())

# Filter passed students
passed = df[df["marks"] >= 50]

# Find topper row (highest marks)
topper = df.loc[df["marks"].idxmax()]

# Save passed students list
passed.to_csv("passed_students.csv", index=False)

print("Topper:")
print(topper)
# Out:
# Topper:
# student_id        104
# name            David
# age                25
# marks            92.0
# subject       Science
# city            Texas
# Name: 3, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df
# Out:
#    student_id     name  age  marks  subject      city
# 0         101    Alice   23   85.0     Math  New York
# 1         102      Bob   24   78.0  Science   Chicago
# 2         103  Charlie   22   82.0     Math  New York
# 3         104    David   25   92.0  Science     Texas
# 4         105      Eva   23   82.0  English   Chicago
# 5         106    Frank   24   67.0     Math     Texas
# 6         107    Grace   22   88.0  English  New York
# 7         108    Helen   23   82.0  Science     Texas

# %%
em1=pd.read_csv("employees_week1.csv")

# %%
em1.head()
# Out:
#               email_id     name               role  company location
# 0      alice@gmail.com    Alice       Data Analyst   Google       NY
# 1        bob@yahoo.com      Bob  Software Engineer   Amazon       TX
# 2  charlie@outlook.com  Charlie        ML Engineer     Meta       CA
# 3      david@gmail.com    David   Backend Engineer  Netflix       WA
# 4        eva@yahoo.com      Eva     Data Scientist   Google       NY

# %%
em1.set_index("email_id", inplace=True)

# %%
em1.columns
# Out:
# Index(['name', 'role', 'company', 'location'], dtype='object')

# %%
em1.index.is_unique
# Out:
# True

# %%
em1
# Out:
#                         name               role  company location
# email_id
# alice@gmail.com        Alice       Data Analyst   Google       NY
# bob@yahoo.com            Bob  Software Engineer   Amazon       TX
# charlie@outlook.com  Charlie        ML Engineer     Meta       CA
# david@gmail.com        David   Backend Engineer  Netflix       WA
# eva@yahoo.com            Eva     Data Scientist   Google       NY

# %%
em1.reset_index(drop=True, inplace=True)

# %%
em1.head()
# Out:
#       name               role  company location
# 0    Alice       Data Analyst   Google       NY
# 1      Bob  Software Engineer   Amazon       TX
# 2  Charlie        ML Engineer     Meta       CA
# 3    David   Backend Engineer  Netflix       WA
# 4      Eva     Data Scientist   Google       NY

# %%
#Example dataframe
edf = pd.DataFrame({
    "Name" : ["Alice", "Bob", "Charlie"],
    "Age" : [24, 27, 22],
    "Marks": [88, 92, 87]
},index= [101, 102, 103])

# %%
edf.head()
# Out:
#         Name  Age  Marks
# 101    Alice   24     88
# 102      Bob   27     92
# 103  Charlie   22     87

# %%
edf.loc[101]
# Out:
# Name     Alice
# Age         24
# Marks       88
# Name: 101, dtype: object

# %%
edf.loc[[101,103]]
# Out:
#         Name  Age  Marks
# 101    Alice   24     88
# 103  Charlie   22     87

# %%
edf.loc[101:103]
# Out:
#         Name  Age  Marks
# 101    Alice   24     88
# 102      Bob   27     92
# 103  Charlie   22     87

# %%
edf.loc[:,"Name"]
# Out:
# 101      Alice
# 102        Bob
# 103    Charlie
# Name: Name, dtype: object

# %%
edf
# Out:
#         Name  Age  Marks
# 101    Alice   24     88
# 102      Bob   27     92
# 103  Charlie   22     87

# %%
edf.loc[ : , ["Name", "Marks"]]
# Out:
#         Name  Marks
# 101    Alice     88
# 102      Bob     92
# 103  Charlie     87

# %%
edf.loc[102,"Marks"]
# Out:
# 92

# %%
edf.loc[edf["Marks"]<90]
# Out:
#         Name  Age  Marks
# 101    Alice   24     88
# 103  Charlie   22     87

# %%
edf.loc[edf["Marks"]>90, ["Name", "Marks"]]
# Out:
#     Name  Marks
# 102  Bob     92

# %%
edf.loc[edf["Marks"]<=90, "Marks"] += 5

# %%
edf.head()
# Out:
#         Name  Age  Marks
# 101    Alice   24     93
# 102      Bob   27     92
# 103  Charlie   22     92

# %%
edf.reset_index(drop = True, inplace=True)

# %%
edf   # we can see the index is reset to default 0,1,2
# Out:
#       Name  Age  Marks
# 0    Alice   24     93
# 1      Bob   27     92
# 2  Charlie   22     92

# %%
edf.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
edf.set_index("Name", inplace=True)

# %%
edf
# Out:
#          Age  Marks
# Name
# Alice     24     93
# Bob       27     92
# Charlie   22     92

# %%
edf.reset_index(inplace=True)

# %%
edf
# Out:
#       Name  Age  Marks
# 0    Alice   24     93
# 1      Bob   27     92
# 2  Charlie   22     92

# %%
edf.index = range(100, 100+len(edf))

# %%
edf
# Out:
#         Name  Age  Marks
# 100    Alice   24     93
# 101      Bob   27     92
# 102  Charlie   22     92

# %%
edf.at[101, "Marks"]
# Out:
# 92

# %%
edf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 101 to 103
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Marks   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
s = pd.read_csv("employees_activity.csv")# s is the dataframe variable

# %%
s.dtypes
# Out:
# employee_id      int64
# email           object
# name            object
# role            object
# company         object
# city            object
# experience       int64
# joining_date    object
# last_login      object
# salary           int64
# dtype: object

# %%
s.head()# display first 5 rows of the dataframe
# Out:
#    employee_id                email     name               role  company  \
# 0          101      alice@gmail.com    Alice       Data Analyst   Google
# 1          102        bob@yahoo.com      Bob  Software Engineer   Amazon
# 2          103  charlie@outlook.com  Charlie        ML Engineer     Meta
# 3          104      david@gmail.com    David   Backend Engineer  Netflix
# 4          105        eva@yahoo.com      Eva     Data Scientist   Google
#
#          city  experience joining_date  last_login  salary
# 0    New York           2   2022-06-15  2024-03-10   85000
# 1       Texas           3   2021-08-01  2024-03-12   95000
# 2  California           4   2020-01-20  2024-03-08  120000
# 3  Washington           5   2019-11-05  2024-03-01  130000
# 4    New York           3   2021-04-18  2024-03-11  110000

# %%
s["email"]= s["email"].astype("string")
# changing the data type of email column to string

# %%
s.dtypes["email"]
# Out:
# string[python]

# %%
# converting the multiple column data types
s = s.astype(
    {"email": "string",
     "employee_id": "int64",
     "name": "string",
     "company" : "string",
     "role": "string",
     "salary": "float64",
     "city" : "string"}
)

# %%
s.dtypes
# Out:
# employee_id              int64
# email           string[python]
# name            string[python]
# role            string[python]
# company         string[python]
# city            string[python]
# experience               int64
# joining_date            object
# last_login              object
# salary                 float64
# dtype: object

# %%
s["joining_date"] = pd.to_datetime(s["joining_date"])
s["last_login"] = pd.to_datetime(s["last_login"])

# %%
s.dtypes
# Out:
# employee_id              int64
# email           string[python]
# name            string[python]
# role            string[python]
# company         string[python]
# city            string[python]
# experience               int64
# joining_date    datetime64[ns]
# last_login      datetime64[ns]
# salary                 float64
# dtype: object

# %%
s["email"]= s["email"].str.lower().str.strip()
# str.strip() will clean the email column by removing leading/trailing spaces
# str.lower() will convert the email column to lowercase

# %%
s.head()
# Out:
#    employee_id                email     name               role  company  \
# 0          101      alice@gmail.com    Alice       Data Analyst   Google
# 1          102        bob@yahoo.com      Bob  Software Engineer   Amazon
# 2          103  charlie@outlook.com  Charlie        ML Engineer     Meta
# 3          104      david@gmail.com    David   Backend Engineer  Netflix
# 4          105        eva@yahoo.com      Eva     Data Scientist   Google
#
#          city  experience joining_date last_login    salary
# 0    New York           2   2022-06-15 2024-03-10   85000.0
# 1       Texas           3   2021-08-01 2024-03-12   95000.0
# 2  California           4   2020-01-20 2024-03-08  120000.0
# 3  Washington           5   2019-11-05 2024-03-01  130000.0
# 4    New York           3   2021-04-18 2024-03-11  110000.0

# %%
s[s["email"].str.contains("david@gmail.com")]
# Out:
#    employee_id            email   name              role  company        city  \
# 3          104  david@gmail.com  David  Backend Engineer  Netflix  Washington
#
#    experience joining_date last_login    salary
# 3           5   2019-11-05 2024-03-01  130000.0

# %%
s[s["email"].str.contains("david@gmail.com",case=False, na=False)]
# case=False makes the search case insensitive
# na=False will ignore NaN values while searching
# Out:
#    employee_id            email   name              role  company        city  \
# 3          104  david@gmail.com  David  Backend Engineer  Netflix  Washington
#
#    experience joining_date last_login    salary
# 3           5   2019-11-05 2024-03-01  130000.0

# %%
s["Summary"]= s["salary"].apply(lambda x: "Good Salary" if x>=80000 else "Less Salary")

# %%
s
# Out:
#    employee_id                email     name               role    company  \
# 0          101      alice@gmail.com    Alice       Data Analyst     Google
# 1          102        bob@yahoo.com      Bob  Software Engineer     Amazon
# 2          103  charlie@outlook.com  Charlie        ML Engineer       Meta
# 3          104      david@gmail.com    David   Backend Engineer    Netflix
# 4          105        eva@yahoo.com      Eva     Data Scientist     Google
# 5          106      frank@gmail.com    Frank       Data Analyst     Amazon
# 6          107    grace@outlook.com    Grace        ML Engineer       Meta
# 7          108      helen@gmail.com    Helen  Software Engineer  Microsoft
# 8          109       ivan@yahoo.com     Ivan   Backend Engineer    Netflix
# 9          110       jane@gmail.com     Jane     Data Scientist     Google
#
#          city  experience joining_date last_login    salary      Summary
# ...

# %%
ew1= pd.read_csv("employees_week1.csv")
ew2= pd.read_csv("employees_week2.csv")

# %%
ew1.head(2)
# Out:
#           email_id   name               role company location
# 0  alice@gmail.com  Alice       Data Analyst  Google       NY
# 1    bob@yahoo.com    Bob  Software Engineer  Amazon       TX

# %%
ew2.head(2)
# Out:
#           email_id   name                 role    company location
# 0  alice@gmail.com  Alice  Senior Data Analyst     Google       NY
# 1    bob@yahoo.com    Bob    Software Engineer  Microsoft       TX

# %%
pd.merge(ew1, ew2, on="email_id", how="inner")
# Out:
#               email_id   name_x             role_x company_x location_x  \
# 0      alice@gmail.com    Alice       Data Analyst    Google         NY
# 1        bob@yahoo.com      Bob  Software Engineer    Amazon         TX
# 2  charlie@outlook.com  Charlie        ML Engineer      Meta         CA
# 3      david@gmail.com    David   Backend Engineer   Netflix         WA
# 4        eva@yahoo.com      Eva     Data Scientist    Google         NY
#
#     name_y                 role_y  company_y location_y
# 0    Alice    Senior Data Analyst     Google         NY
# 1      Bob      Software Engineer  Microsoft         TX
# 2  Charlie            ML Engineer       Meta         CA
# 3    David       Backend Engineer    Netflix         WA
# 4      Eva  Senior Data Scientist     Google         NY

# %%
merged=pd.merge(ew1[["email_id","company","location"]], ew2[["email_id","company","location"]], on="email_id", how="inner", suffixes=("_old", "_new"))
#if we didn't mentioned suffixes parameter, then it will take default suffixes _x and _y
#merged= ew1["email_id","company","location"].merge(ew2["email_id","company","location"], on="email_id", how="inner")

# %%
merged
# Out:
#               email_id company_old location_old company_new location_new
# 0      alice@gmail.com      Google           NY      Google           NY
# 1        bob@yahoo.com      Amazon           TX   Microsoft           TX
# 2  charlie@outlook.com        Meta           CA        Meta           CA
# 3      david@gmail.com     Netflix           WA     Netflix           WA
# 4        eva@yahoo.com      Google           NY      Google           NY

# %%
pd.concat([ew1, ew2]) # row-wise concatenation
# Out:
#               email_id     name                   role    company location
# 0      alice@gmail.com    Alice           Data Analyst     Google       NY
# 1        bob@yahoo.com      Bob      Software Engineer     Amazon       TX
# 2  charlie@outlook.com  Charlie            ML Engineer       Meta       CA
# 3      david@gmail.com    David       Backend Engineer    Netflix       WA
# 4        eva@yahoo.com      Eva         Data Scientist     Google       NY
# 0      alice@gmail.com    Alice    Senior Data Analyst     Google       NY
# 1        bob@yahoo.com      Bob      Software Engineer  Microsoft       TX
# 2  charlie@outlook.com  Charlie            ML Engineer       Meta       CA
# 3      david@gmail.com    David       Backend Engineer    Netflix       WA
# 4        eva@yahoo.com      Eva  Senior Data Scientist     Google       NY

# %%
pd.concat([ew1, ew2], ignore_index=True)
# Out:
#               email_id     name                   role    company location
# 0      alice@gmail.com    Alice           Data Analyst     Google       NY
# 1        bob@yahoo.com      Bob      Software Engineer     Amazon       TX
# 2  charlie@outlook.com  Charlie            ML Engineer       Meta       CA
# 3      david@gmail.com    David       Backend Engineer    Netflix       WA
# 4        eva@yahoo.com      Eva         Data Scientist     Google       NY
# 5      alice@gmail.com    Alice    Senior Data Analyst     Google       NY
# 6        bob@yahoo.com      Bob      Software Engineer  Microsoft       TX
# 7  charlie@outlook.com  Charlie            ML Engineer       Meta       CA
# 8      david@gmail.com    David       Backend Engineer    Netflix       WA
# 9        eva@yahoo.com      Eva  Senior Data Scientist     Google       NY

# %%
pd.concat([ew1, ew2], ignore_index=True,axis=1)
# Out:
#                      0        1                  2        3   4  \
# 0      alice@gmail.com    Alice       Data Analyst   Google  NY
# 1        bob@yahoo.com      Bob  Software Engineer   Amazon  TX
# 2  charlie@outlook.com  Charlie        ML Engineer     Meta  CA
# 3      david@gmail.com    David   Backend Engineer  Netflix  WA
# 4        eva@yahoo.com      Eva     Data Scientist   Google  NY
#
#                      5        6                      7          8   9
# 0      alice@gmail.com    Alice    Senior Data Analyst     Google  NY
# 1        bob@yahoo.com      Bob      Software Engineer  Microsoft  TX
# 2  charlie@outlook.com  Charlie            ML Engineer       Meta  CA
# 3      david@gmail.com    David       Backend Engineer    Netflix  WA
# 4        eva@yahoo.com      Eva  Senior Data Scientist     Google  NY

# %%
ew1.compare(ew2)# in my opinion it is waste of comparing all unneccessary columns, so we can use merge method for sorting the columns to be compared.
# Out:
#              role                        company
#              self                  other    self      other
# 0    Data Analyst    Senior Data Analyst     NaN        NaN
# 1             NaN                    NaN  Amazon  Microsoft
# 4  Data Scientist  Senior Data Scientist     NaN        NaN

# %%
changed_company = ew1["company"] != ew2["company"]   
changed_company
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: company, dtype: bool

# %%
ew1.loc[changed_company]
# Out:
#         email_id name               role company location
# 1  bob@yahoo.com  Bob  Software Engineer  Amazon       TX

# %%
changed_role = ew1["role"] != ew2["role"]

# %%
changed=ew1[changed_company | changed_role]   
changed
 #it will store only ew1 rows which are changed company or role
 # if we need ew2 rows then we can do similarly
# Out:
#           email_id   name               role company location
# 0  alice@gmail.com  Alice       Data Analyst  Google       NY
# 1    bob@yahoo.com    Bob  Software Engineer  Amazon       TX
# 4    eva@yahoo.com    Eva     Data Scientist  Google       NY

# %%
changed.loc[changed_role,"status"] = "role_changed"
changed.loc[changed_company,"status"] = "company_changed"

# %%
changed.head()
# Out:
#           email_id   name               role company location           status
# 0  alice@gmail.com  Alice       Data Analyst  Google       NY     role_changed
# 1    bob@yahoo.com    Bob  Software Engineer  Amazon       TX  company_changed
# 4    eva@yahoo.com    Eva     Data Scientist  Google       NY     role_changed

# %%
# importing the pandas library as pd for simple and easy access
import pandas as pd

# %%
# Assigning the variable names to the files to be read
emp1= r"C:\Users\Narasimha\Desktop\Agent2_sample\scrapers\data\raw\employees_past_week.csv"
emp2= r"C:\Users\Narasimha\Desktop\Agent2_sample\scrapers\data\raw\employees_present_week.csv"

# %%
# Define the columns to be used and their data types
USECOLS =[0,1,2,3,4]
DTYPES={ 0: "string",
         1: "string",
         2: "string",
         3: "string",
         4: "string"
       }

# %%
df1= pd.read_csv(emp1, usecols=USECOLS, dtype=DTYPES, index_col = False)
df2= pd.read_csv(emp2, usecols=USECOLS, dtype=DTYPES, index_col=False)

# %%
df1.columns= ["email_id", "name","role", "company_name", "company_location"]
df2.columns= ["email_id", "name","role", "company_name", "company_location"]

# %%
# clean data by removing leading/trailing spaces and converting to lowercase
for df in [df1,df2]:
    df["email_id"]= df["email_id"].str.lower().str.strip()
    df["name"]= df["name"].str.lower().str.strip()
    df["role"]= df["role"].str.lower().str.strip()
    df["company_name"]= df["company_name"].str.lower().str.strip()
    df["company_location"]= df["company_location"].str.lower().str.strip()

# %%
#merge only needed columns to identify changes
merged=df1[["email_id", "role", "company_name", "company_location"]].merge(
    df2[["email_id", "role", "company_name"]],
    on="email_id",
    how="inner",
    suffixes=("_old", "_new")
)
merged.head()
# Out:
#                 email_id            role_old  company_name_old  \
# 0      john.doe@acme.com   software engineer  acme corporation
# 1  jane.smith@globex.com     product manager       globex inc.
# 2   robert.j@initech.com        data analyst           initech
# 3   emily.c@umbrella.com  marketing director     umbrella corp
# 4    michael.b@hooli.com                 cto             hooli
#
#   company_location            role_new  company_name_new
# 0    san francisco   software engineer  acme corporation
# 1         new york     product manager       globex inc.
# 2           boston        data analyst           initech
# 3           london  marketing director     umbrella corp
# 4        palo alto                 cto             hooli

# %%
# Identify changes in company_name and role
company_changed = merged["company_name_old"] != merged["company_name_new"]
role_changed = merged["role_old"] != merged["role_new"]
role_changed.head()  # it will store boolean values indicating if role has changed
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: boolean

# %%
#creation of new dataset with changes only
changed_rows= merged[company_changed | role_changed].copy()
changed_rows.loc[role_changed,"status"]= "role changed"
changed_rows.loc[company_changed, "status"]= "company_changed"
changed_rows.tail()
# Out:
#                    email_id                       role_old  \
# 65    sienna.b@crescent.com                operations lead
# 84     logan.k@serenity.com             healthcare analyst
# 123       laura.d@avant.com  business intelligence analyst
# 124    julian.h@maxwell.com             investment analyst
# 138  tristan.h@datacore.com   data infrastructure engineer
#
#         company_name_old company_location                       role_new  \
# 65    crescent solutions         new york                operations lead
# 84       serenity health           london             healthcare analyst
# 123             avant bi           london  business intelligence analyst
# 124  maxwell investments          toronto          investment strategist
# 138             datacore           boston        data solutions engineer
#
#         company_name_new           status
# 65       crescent global  company_changed
# 84       serenity global  company_changed
# ...

# %%
changed_rows["Company (Location)"] = (
    changed_rows["company_name_old"] + "(" + changed_rows["company_location"] + ")" ).copy()

# %%
new_dataset= changed_rows[["email_id", "Company (Location)", "role_old", "status"]].copy()

# %%
new_dataset
# Out:
#                    email_id            Company (Location)  \
# 16         chris.p@apex.com        apex solutions(dublin)
# 19     sophia.t@everest.com    everest consulting(zurich)
# 21    victoria.n@lumina.com      lumina designs(new york)
# 22        mark.d@fusion.com        fusion robotics(tokyo)
# 23      paula.s@quantum.com         quantum ai(singapore)
# 26       brian.c@altair.com      altair security(chicago)
# 30      rachel.p@cypher.com             cypher ai(london)
# 47     hailey.d@monarch.com    monarch industries(london)
# 50        colin.b@astro.com          astro cloud(chicago)
# 55       ariana.l@polar.com        polar studios(toronto)
# 65    sienna.b@crescent.com  crescent solutions(new york)
# 84     logan.k@serenity.com       serenity health(london)
# 123       laura.d@avant.com              avant bi(london)
# 124    julian.h@maxwell.com  maxwell investments(toronto)
# 138  tristan.h@datacore.com              datacore(boston)
#
# ...
