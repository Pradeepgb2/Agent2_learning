# %%
"""import pandas as pd
import requests
import os
from pathlib import Path
from datetime import datetime
from dotenv import load_dotenv
load_dotenv()"""
# Out:
# 'import pandas as pd\nimport requests\nimport os\nfrom pathlib import Path\nfrom datetime import datetime\nfrom dotenv import load_dotenv\nload_dotenv()'

# %%
#API_KEY = os.getenv('API_KEY')
#DATASET_ID = os.getenv("DATASET_ID")
#url="https://www.kaggle.com/datasets/pradeepgubbala/employees"

# %%
"""headers = {
    "Authorization":  f"Bearer {API_KEY}",
    #"Accept": "application/octet-stream"
}

"""
# Out:
# 'headers = {\n    "Authorization":  f"Bearer {API_KEY}",\n    #"Accept": "application/octet-stream"\n}\n\n'

# %%
"""today_date = datetime.now().strftime("%Y-%m-%d")
filename = f"employees_dataset_{today_date}.csv"""
# Out:
# 'today_date = datetime.now().strftime("%Y-%m-%d")\nfilename = f"employees_dataset_{today_date}.csv'

# %%
"""output_dir = Path("datasets")
output_dir.mkdir(exist_ok=True)
file_path = output_dir / filename"""
# Out:
# 'output_dir = Path("datasets")\noutput_dir.mkdir(exist_ok=True)\nfile_path = output_dir / filename'

# %%
"""response = requests.get(url, headers=headers)
response.raise_for_status()  # it will stop if request fails"""
# Out:
# 'response = requests.get(url, headers=headers)\nresponse.raise_for_status()  # it will stop if request fails'

# %%
"""with open("f.csv", "wb") as f:
    f.write(response.content)

#print(f"Downloaded dataset → {file_path}")

# -------------------------
# READ INTO PANDAS
# -------------------------
df = pd.read_csv("f.csv")
print(df.head())
"""
# Out:
# 'with open("f.csv", "wb") as f:\n    f.write(response.content)\n\n#print(f"Downloaded dataset → {file_path}")\n\n# -------------------------\n# READ INTO PANDAS\n# -------------------------\ndf = pd.read_csv("f.csv")\nprint(df.head())\n'

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv('API_KEY')
os.environ['KAGGLE_USERNAME'] = 'pradeepgubbala'
os.environ['KAGGLE_KEY'] = API_KEY

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
dataset = 'pradeepgubbala/employees'
download_path = './employees_dataset'

# %%
api.dataset_download_file(dataset,file_name='employees_present_week.csv', path=download_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/pradeepgubbala/employees
# False
